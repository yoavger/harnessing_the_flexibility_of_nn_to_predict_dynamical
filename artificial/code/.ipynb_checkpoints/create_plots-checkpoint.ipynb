# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from bayesian_fit import *
from q_pred_ns import *
from q_fit import *
from q_pred import * 

import warnings
warnings.filterwarnings('ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def bce_loss(y_hat,y_true):
    eps = 1e-10
    return (-((y_true*(np.log(y_hat + eps)) + (1-y_true)*(np.log(1-y_hat + eps)))))

def MSE(y_true,y_hat):
    return ((y_hat - y_true)**2).mean()

# %%
df = pd.read_csv('../data/90_artificial_test_agents.csv')

num_of_agent = df['agent'].nunique() # agent
num_of_action = df['action'].nunique()
num_of_trials = df['trial'].nunique() # trial_num

all_data = []

for i in range(num_of_agent):
    cur_df = df[(df['agent']==i)].reset_index()  # agent_index
    all_data.append(cur_df)

# %%
all_p_0_qps = []
bce_arr_qps = []
p_r2_arr_qps = []
norm_ll_arr_qps = []

alpha_qps, beta_qps = [],[]
mse_alpha_qps, mse_beta_qps = [],[]

for i in range(num_of_agent):
    
    res = q_fit(all_data[i])
    acc,p_0 = q_pred(all_data[i],res.x)
    
    all_p_0_qps.append(p_0)
    alpha_qps.append(res.x[0])
    beta_qps.append(res.x[1])
    
    loss = bce_loss(1 - p_0, all_data[i].action.values)
    bce_arr_qps.append(loss.mean())
    p_r2_arr_qps.append( 1 - (np.array(loss.sum()) / (-len(all_data[i])*np.log(0.5))))
    norm_ll_arr_qps.append(np.exp(-loss.mean()))
    
    mse_alpha_qps.append((MSE(all_data[i]['alpha']    , np.repeat(alpha_qps[i]   ,num_of_trials) ) ))
    mse_beta_qps.append((MSE(all_data[i]['beta']/10  ,  np.repeat(beta_qps[i]/10 ,num_of_trials) ) ))
    
print('QPS BCE '       , np.array(bce_arr_qps).mean()   )
print('QPS MSE alpha ' , np.array(mse_alpha_qps).mean() )
print('QPS MSE beta '  , np.array(mse_beta_qps).mean()  )
# Out:
# QPS BCE  0.5375094150851328
# QPS MSE alpha  0.08610518167357183
# QPS MSE beta  0.17817842948271528

# %%
w = []
for i in range(num_of_agent):
    obs = all_data[i][['action','reward']].values
    w.append(bayesian_fit(obs))

alpha_bay = [ 1 / (1 + np.exp(-w[i][0][:,2])) for i in range(num_of_agent) ]
beta_bay =  [ (np.exp(w[i][0][:,3])).clip(0,10) for i in range(num_of_agent) ]

# all_p_0 = [ (w[i][2].mean(axis=1)) for i in range(num_of_agent) ]
bce_arr = np.array([ (-np.log(w[i][1].mean(axis=1))).mean() for i in range(num_of_agent)])
# p_r2_arr = np.array([ 1-(np.sum(-np.log(w[i][1].mean(axis=1)))/(-len(all_data[i])*np.log(0.5))) for i in range(num_of_agent)])
# norm_ll_arr = np.array([ np.exp((np.log(w[i][1].mean(axis=1))).mean()) for i in range(num_of_agent)])

all_p_0_bay = []
bce_arr_bay = []
p_r2_arr_bay = []
norm_ll_arr_bay = []

mse_alpha_bay, mse_beta_bay = [],[]

for i in range(num_of_agent):
    
    x = pd.Series(alpha_bay[i]).shift(0, fill_value=0.5).values
    y = pd.Series(beta_bay[i]).shift(0, fill_value=5).values
    
    pp = np.array([x,y]).T

    acc,p_0 = q_pred_ns(all_data[i],pp)
    all_p_0_bay.append(p_0)
    
    loss = bce_loss(1 - p_0, all_data[i].action.values)
    bce_arr_bay.append(loss.mean())
    p_r2_arr_bay.append( 1 - (np.array(loss.sum()) / (-len(all_data[i])*np.log(0.5))))
    norm_ll_arr_bay.append(np.exp(-loss.mean()))
    
    mse_alpha_bay.append((MSE(all_data[i]['alpha']    , alpha_bay[i]   ) ))
    mse_beta_bay.append((MSE(all_data[i]['beta']/10  , beta_bay[i]/10  ) ))
    
print('BAY BCE '       , np.array(bce_arr_bay).mean()   )
print('BAY MSE alpha ' , np.array(mse_alpha_bay).mean() )
print('BAY MSE beta '  , np.array(mse_beta_bay).mean()  )
# Out:
# BAY BCE  0.5065828632289807
# BAY MSE alpha  0.12084825997493442
# BAY MSE beta  0.11057411141372832

# %%
class GRU_RNN_TWO(nn.Module):
        
    def __init__(self,input_size, hidden_size, num_of_layers, num_alpha_embedding, num_beta_embedding, output_size, dropout):
        
        super(GRU_RNN_TWO, self).__init__()
        
        self.input_size = input_size
        self.num_alpha_embedding = num_alpha_embedding
        self.num_beta_embedding = num_beta_embedding        
        
        self.hidden_0 = nn.GRU(  
                    input_size=input_size,
                    hidden_size=hidden_size,
                    num_layers=num_of_layers,
                    batch_first=True,
                    dropout=dropout
        )
        
        self.hidden_1 = nn.GRU(  
                    input_size=input_size + num_alpha_embedding + num_beta_embedding,
                    hidden_size=hidden_size,
                    num_layers=num_of_layers,
                    batch_first=True,
                    dropout=dropout 
        )
    
        
        self.out_alpha = nn.Linear(hidden_size, num_alpha_embedding)
        self.out_beta = nn.Linear(hidden_size, num_beta_embedding)
        
        self.relu_alpha = nn.ReLU()
        self.relu_beta = nn.ReLU()

        self.reg_alpha = nn.Linear(num_alpha_embedding, 1)
        self.reg_beta = nn.Linear(num_beta_embedding, 1)

        
        self.out_action = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):

        # parameters estimation
        output_0, hn_0 = self.hidden_0(x)
        
        output_alpha = self.out_alpha(output_0)
        output_alpha = self.relu_alpha(output_alpha)
        
        output_beta = self.out_beta(output_0)
        output_beta = self.relu_beta(output_beta)
        
        cont_output_alpha = self.reg_alpha(output_alpha)
        cont_output_beta = self.reg_beta(output_beta)
    
        # concat input 
        input_1 = torch.cat([x[0],output_alpha[0],output_beta[0]],dim=1) # cat # concat
        input_1 = input_1.reshape(1,x.shape[1],self.input_size + self.num_alpha_embedding
                                  + self.num_beta_embedding)
        
        # action predication
        output_action, hn_1 = self.hidden_1(input_1)
        output_action = self.out_action(output_action)
        output_action = F.softmax(output_action,dim=-1)
        
        output_dis = [output_alpha, output_beta]
        output_cont = [cont_output_alpha, cont_output_beta]

        return output_dis, output_cont, output_action, hn_0, hn_1

# %%
class behavior_dataset(Dataset):
    """ 
    Transform Dataframe of an agent to torch Dataset class 
    
    Args:
        dataframe: pandas dataframe of agent behavior 
        n_parameters_embedding: number of parameters embedding class
        
    Returns: 
        torch Dataset:
        x: [reward_(t-1) , action_(t-1)] action are encoded as one-hot vectors
        y: [action_t, parameter embedding] action and parameters are encoded as one-hot vectors
        
    """
    def __init__(self,dataframe):
        
        # action one hot transformation 
        action = np.array(dataframe['action'])
        if np.all(action == action[0]):
            action = np.append(action,(1-action[0]))
            action = torch.tensor((action).reshape(len(dataframe) + 1),dtype=int)
            action_onehot = nn.functional.one_hot(action, len(action.unique()))
            # delete last one
            action_onehot = action_onehot[:-1]
        else:
            action = torch.tensor((action).reshape(len(dataframe)),dtype=int)
            action_onehot = nn.functional.one_hot(action, len(action.unique()))
        
        # reward
        reward = torch.tensor((np.array(dataframe['reward'])).reshape(len(dataframe)),dtype=int)
        
        # concatinating reward and action
        reward_action = torch.cat([reward[ :, np.newaxis], action_onehot],1)
        
        # adding dummy zeros to the beginning and ignoring the last one
        reward_action_shift = nn.functional.pad(reward_action,[0,0,1,0])[:-1]
        
        
        # network input 
        x = reward_action_shift
        
#         n_blocks = int(len(dataframe)/100)
#         x.reshape(n_blocks,100,3)[:,0,:] = torch.zeros(size=(n_blocks,3))
    
        y = action_onehot
  
        self.x = x.type(dtype=torch.float32)
        self.y = y.type(dtype=torch.float32)
        self.len = len(dataframe)

    def __getitem__(self,idx):
        return self.x[idx],self.y[idx]
  
    def __len__(self):
        return self.len    
    
class merge_behavior_dataset(Dataset):
    """ 
    Merge Dataset of each agent to one dataset
    
    Args:
        dataset_list: list of Dataset of all agent 
        n_trials: num_of_trials each agent was simulated
        
    Returns: 
        torch Dataset:
        x: [reward_(t-1) , action_(t-1)] all agents
        y: [action_t, parameter embedding] all agents
        
    """
    def __init__(self, dataset_list, n_trials):
        X = []
        Y = []
        for j,agent in enumerate(dataset_list):
            for i in range(n_trials[j]):
                X.append(agent[i][0])
                Y.append(agent[i][1])
                
        self.x = torch.stack(X).type(dtype=torch.float32)
        self.y = torch.stack(Y).type(dtype=torch.float32)
        self.len = len(X)   
    
    def __getitem__(self,idx):
        return self.x[idx],self.y[idx]
  
    def __len__(self):
        return self.len
    
all_data_rnn = []

for i in range(num_of_agent):
    cur_df = all_data[i]
    cur_df = cur_df.reset_index()
    all_data_rnn.append(behavior_dataset(cur_df))
    
val_dataset = merge_behavior_dataset(all_data_rnn, np.repeat(num_of_trials,num_of_agent))

load = torch.load(f'checkpoint_best_val_70.pth',map_location='cpu')

INPUT_SIZE = 3
aHidden = 32
num_alpha_embedding = 5
num_beta_embedding = 5
OUTPUT_SIZE = 2

rnn = GRU_RNN_TWO(
              input_size=INPUT_SIZE,
              hidden_size=aHidden,
              num_of_layers=1,
              num_alpha_embedding=num_alpha_embedding,
              num_beta_embedding=num_beta_embedding,
              output_size=OUTPUT_SIZE,
              dropout=0
            )

rnn.load_state_dict(load['model_state'])
print(load['epoch'])
rnn.eval()
# Out:
# 54
# GRU_RNN_TWO(
#   (hidden_0): GRU(3, 32, batch_first=True)
#   (hidden_1): GRU(13, 32, batch_first=True)
#   (out_alpha): Linear(in_features=32, out_features=5, bias=True)
#   (out_beta): Linear(in_features=32, out_features=5, bias=True)
#   (relu_alpha): ReLU()
#   (relu_beta): ReLU()
#   (reg_alpha): Linear(in_features=5, out_features=1, bias=True)
#   (reg_beta): Linear(in_features=5, out_features=1, bias=True)
#   (out_action): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
alpha_trnn = []
beta_trnn = []
all_p_0_trnn = []

j = 0

for i in range(num_of_agent):
        
    cur_df = all_data[i]
    
    num_of_trials = len(cur_df)
        
    y_hat_dis, y_hat_cont, y_hat_action, _, _ = rnn((val_dataset[j:num_of_trials+j][0].reshape(1,num_of_trials,3)))
    y_hat_action = (y_hat_action.view(-1, num_of_action)) 
    
    alpha_trnn.append((y_hat_cont[0].cpu().detach().numpy().flatten()))    
    beta_trnn.append((y_hat_cont[1].cpu().detach().numpy().flatten()))
    all_p_0_trnn.append(((y_hat_action[:,0]).cpu().detach().numpy()))
    
    j += num_of_trials
    
bce_arr_trnn = []
p_r2_arr_trnn = []
norm_ll_arr_trnn = []
mse_alpha_trnn, mse_beta_trnn = [],[]

for i in range(num_of_agent):
    bce = bce_loss(1-all_p_0_trnn[i],all_data[i]['action'])
    bce_arr_trnn.append(bce.mean())
    p_r2_arr_trnn.append(1-(np.array(bce.sum()) / (-len(all_data[i])*np.log(0.5))))
    norm_ll_arr_trnn.append(np.exp(-bce.mean()))
    mse_alpha_trnn.append( ( MSE(all_data[i]['alpha']   ,alpha_trnn[i]      ) ))
    mse_beta_trnn.append(  ( MSE(all_data[i]['beta']/10 ,beta_trnn[i]/10   ) ))
    
print('tRNN BCE '       , np.array(bce_arr_trnn).mean()   )
print('tRNN MSE alpha ' , np.array(mse_alpha_trnn).mean() )
print('tRNN MSE beta '  , np.array(mse_beta_trnn).mean()  )
# Out:
# tRNN BCE  0.40752053583590314
# tRNN MSE alpha  0.05950870913773982
# tRNN MSE beta  0.02328392107697135

# %%
print('QPS BCE %.3f'          %np.array(bce_arr_qps).mean()   )
print('QPS MSE alpha %.3f'    %np.array(mse_alpha_qps).mean() )
print('QPS MSE beta %.3f'     %np.array(mse_beta_qps).mean()  )

print('=============================')

print('BAY BCE %.3f'        %np.array(bce_arr_bay).mean()   )
print('BAY MSE alpha %.3f'  %np.array(mse_alpha_bay).mean() )
print('BAY MSE beta %.3f'   %np.array(mse_beta_bay).mean()  )

print('=============================')

print('tRNN BCE %.3f'        %np.array(bce_arr_trnn).mean()   )
print('tRNN MSE alpha %.3f'  %np.array(mse_alpha_trnn).mean() )
print('tRNN MSE beta %.3f'   %np.array(mse_beta_trnn).mean()  )


all_res = pd.DataFrame({'Measurements':np.concatenate([
                    np.array(bce_arr_qps),np.array(mse_alpha_qps),np.array(mse_beta_qps),
                    np.array(bce_arr_bay),np.array(mse_alpha_bay),np.array(mse_beta_bay),
                    np.array(bce_arr_trnn),np.array(mse_alpha_trnn),np.array(mse_beta_trnn)]),
           
              'Model':
                    np.repeat(['Q-stationary','Bayesian','t-RNN'],3*num_of_agent),
              
              'Type':
                    np.tile(np.repeat([r'$BCE\/\/\/$'+'\n action',r'$MSE_{\alpha}$',r'$MSE_{\beta}$'],num_of_agent),3)
             })

plt.figure(figsize=(5.5,4))
sns.barplot(data=all_res,
            y='Type',x='Measurements',hue='Model',
            palette=['tab:green','#ffc100','#1761B0'],
            edgecolor='k',
            errorbar="se",
            orient='h'
           )

# plt.grid(alpha=0.5,axis='both')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('Erorr (lower is better)',size=22)
plt.ylabel('',size=0)
plt.xlim(0,0.5)
plt.xticks([0.1,0.4])
plt.legend(fontsize=20)
sns.despine()
# plt.savefig('fig_2.pdf',bbox_inches='tight')
plt.show
# Out:
# QPS BCE 0.538
# QPS MSE alpha 0.086
# QPS MSE beta 0.178
# =============================
# BAY BCE 0.507
# BAY MSE alpha 0.121
# BAY MSE beta 0.111
# =============================
# tRNN BCE 0.410
# tRNN MSE alpha 0.042
# tRNN MSE beta 0.029
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('QPS BCE %.3f'          %np.array(bce_arr_qps).mean()   )
print('QPS MSE alpha %.3f'    %np.array(mse_alpha_qps).mean() )
print('QPS MSE beta %.3f'     %np.array(mse_beta_qps).mean()  )

print('=============================')

print('BAY BCE %.3f'        %np.array(bce_arr_bay).mean()   )
print('BAY MSE alpha %.3f'  %np.array(mse_alpha_bay).mean() )
print('BAY MSE beta %.3f'   %np.array(mse_beta_bay).mean()  )

print('=============================')

print('tRNN BCE %.3f'        %np.array(bce_arr_trnn).mean()   )
print('tRNN MSE alpha %.3f'  %np.array(mse_alpha_trnn).mean() )
print('tRNN MSE beta %.3f'   %np.array(mse_beta_trnn).mean()  )


all_res = pd.DataFrame({'Measurements':np.concatenate([
                    np.array(bce_arr_qps),np.array(mse_alpha_qps),np.array(mse_beta_qps),
                    np.array(bce_arr_bay),np.array(mse_alpha_bay),np.array(mse_beta_bay),
                    np.array(bce_arr_trnn),np.array(mse_alpha_trnn),np.array(mse_beta_trnn)]),
           
              'Model':
                    np.repeat(['Q-stationary','Bayesian','t-RNN'],3*num_of_agent),
              
              'Type':
                    np.tile(np.repeat([r'$BCE_{action}$',r'$MSE_{\alpha}$',r'$MSE_{\beta}$'],num_of_agent),3)
             })

fig,ax1 = plt.subplots(1,1,figsize=(5.5,6))
sns.barplot(ax=ax1,data=all_res,
            x='Type',y='Measurements',hue='Model',
            palette=['tab:green','#ffc100','#1761B0'],
            edgecolor='k',
            errorbar="se",
            orient='v'
           )

# plt.grid(alpha=0.5,axis='both')
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.set_ylabel('Erorr (lower is better)',size=22)
ax1.set_xlabel('',size=0)
ax1.set_ylim(0,0.5)
ax1.set_yticks([0.1,0.4])
ax1.legend(fontsize=20)
ax1.set_yticklabels([str(x)[1:] for x in np.round(ax1.get_yticks(), 3)])

sns.despine()
# plt.savefig('fig_2v.pdf',bbox_inches='tight')
plt.show

# %%
pla = ['#D2292D','tab:green','#ffc100','#1761B0']

for i in range(num_of_agent): #[184,185,186,221,241,245,246,267,286,288]:
    
    cur = all_data[i]
    
    fig, (ax0,ax1) = plt.subplots(1,2,figsize=(20,2))
    
    ax0.set_title(f'subj {i}')
    
#     i = 288
    cur = all_data[i]
    
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.alpha,color=pla[0],lw=4) # target
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=np.repeat(alpha_qps[i],num_of_trials),color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=alpha_bay[i],color=pla[2],lw=1,ls=(0, (5, 1)))# bay
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=alpha_trnn[i],color=pla[3],lw=1,ls=(0, (5, 1)))
    
#     i = 185
    cur = all_data[i]
    
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.beta.clip(0,8),color=pla[0],lw=4)
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=np.repeat(beta_qps[i],num_of_trials),color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=beta_bay[i],color=pla[2],lw=1,ls=(0, (5, 1))) # bay
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=beta_trnn[i],color=pla[3],lw=1,ls=(0, (5, 1)))
    
    ax0.set_xticklabels([])
    ax0.set_xlim(0,num_of_trials)
    ax0.set_ylim(-0.2,1.2)
    ax0.set_ylabel(r'$\alpha$',size=30,labelpad=0)
    ax0.set_yticks([.1,.8])
    ax0.set_yticklabels([.1,0.8],size=20)
    ax0.set_yticklabels([str(x)[1:] for x in np.round(ax0.get_yticks(), 3)])
    
    
    ax1.set_xlim(0,num_of_trials)
    ax1.set_ylim(-0.1,10.1)
    ax1.set_ylabel(r'$\beta$',size=30,labelpad=0)
    ax1.set_yticks([1,8])
    ax1.set_yticklabels([1,8],size=20)
    ax1.set_xlabel('Trial',size=22)
    
#     ax0.set_xlim(0,1000)
#     ax0.set_xticks([100,500,900])
#     ax0.set_xticklabels([100,500,900],size=20)
#     ax0.set_xlabel('Trial',size=22)
    
#     ax1.set_xlim(0,1000)
#     ax1.set_xticks([100,500,900])
#     ax1.set_xticklabels([100,500,900],size=20)
    
    from matplotlib.pyplot import Line2D
    legend_elements = [Line2D([0],[0] ,lw=4, color='#D2292D', label='Target')]
    ax0.legend(handles=legend_elements,loc='upper left',fontsize=16)
    
    sns.despine()
#     plt.savefig('fig_223.pdf',bbox_inches='tight')
    plt.show()

# %%
pla = ['#D2292D','tab:green','#ffc100','#1761B0']

for i in range(1): #[184,185,186,221,241,245,246,267,286,288]:
    
    cur = pd.read_csv('alpha.csv')
    
    fig, (ax0,ax1) = plt.subplots(1,2,figsize=(20,2))
    
        
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.target,color=pla[0],lw=4) # target
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.q_sta,color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.bay,color=pla[2],lw=3,ls=(0, (5, 1)))# bay
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.t_rnn,color=pla[3],lw=3,ls=(0, (5, 1)))
    
    cur = pd.read_csv('beta.csv')
    
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.target*2,color=pla[0],lw=4)
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.q_sta*2,color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.bay*2,color=pla[2],lw=3,ls=(0, (5, 1))) # bay
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.t_rnn*2,color=pla[3],lw=3,ls=(0, (5, 1)))
    

    ax0.set_xlim(0,num_of_trials)
    ax0.set_ylim(-0.2,1.2)
    ax0.set_ylabel(r'$\alpha$',size=30,labelpad=0)
    ax0.set_yticks([.1,.8])
    ax0.set_yticklabels([.1,0.8],size=20)
    ax0.set_yticklabels([str(x)[1:] for x in np.round(ax0.get_yticks(), 3)])
    
    
    ax1.set_xlim(0,num_of_trials)
    ax1.set_ylim(-0.1,10.1)
    ax1.set_ylabel(r'$\beta$',size=30,labelpad=0)
    ax1.set_yticks([1,8])
    ax1.set_yticklabels([1,8],size=20)
    ax1.set_xlabel('Trial',size=22)
    
    ax0.set_xlim(0,1000)
    ax0.set_xticks([100,500,900])
    ax0.set_xticklabels([100,500,900],size=20)
    ax0.set_xlabel('Trial',size=22)
    

    ax1.set_xlim(0,1000)
    ax1.set_xticks([100,500,900])
    ax1.set_xticklabels([100,500,900],size=20)
    
#     from matplotlib.pyplot import Line2D
#     legend_elements = [Line2D([0],[0] ,lw=3, color='#D2292D', label='Target')]
#     ax0.legend(handles=legend_elements,loc='upper left',fontsize=16)
    
        
    sns.despine()
    plt.savefig('fig_232.pdf',bbox_inches='tight')
    plt.show()

# %%
pla = ['#D2292D','tab:green','#ffc100','#1761B0']

for i in range(1): #[184,185,186,221,241,245,246,267,286,288]:
    i = 58
    cur = all_data[i]

    fig, (ax0,ax1) = plt.subplots(1,2,figsize=(20,2))
    
#     ax0.set_title(f'subj {i}')
    
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=cur.alpha,color=pla[0],lw=4) # target
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=np.repeat(alpha_qps[i],num_of_trials),color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=alpha_bay[i],color=pla[2],lw=3,ls=(0, (5, 1)))# bay
    sns.lineplot(ax=ax0,x=np.arange(num_of_trials),y=alpha_trnn[i],color=pla[3],lw=3,ls=(0, (5, 1)))
    

    
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=cur.beta,color=pla[0],lw=4)
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=np.repeat(beta_qps[i],num_of_trials),color=pla[1],lw=3,ls=(0, (5, 1))) # qps
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=beta_bay[i],color=pla[2],lw=3,ls=(0, (5, 1))) # bay
    sns.lineplot(ax=ax1,x=np.arange(num_of_trials),y=beta_trnn[i],color=pla[3],lw=3,ls=(0, (5, 1)))
    
    ax0.set_xticklabels([])
    ax0.set_xlim(0,num_of_trials)
    ax0.set_ylim(-0.2,1.2)
    ax0.set_ylabel(r'$\alpha$',size=30,labelpad=0)
    ax0.set_yticks([.1,.8])
    ax0.set_yticklabels([.1,0.8],size=20)
    ax0.set_yticklabels([str(x)[1:] for x in np.round(ax0.get_yticks(), 3)])
    
    
    ax1.set_xlim(0,num_of_trials)
    ax1.set_ylim(-0.1,10.1)
    ax1.set_ylabel(r'$\beta$',size=30,labelpad=0)
    ax1.set_yticks([1,8])
    ax1.set_yticklabels([1,8],size=20)
    ax1.set_xlabel('Trial',size=22)
    
    
    ax0.set_xlim(0,1000)
    ax0.set_xticks([100,500,900])
    ax0.set_xticklabels([100,500,900],size=20)
    ax0.set_xlabel('Trial',size=22)
    
    ax0.set_xlim(0,1000)
    ax1.set_xlim(0,1000)
    ax1.set_xticks([100,500,900])
    ax1.set_xticklabels([100,500,900],size=20)
    
    from matplotlib.pyplot import Line2D
    legend_elements = [Line2D([0],[0] ,lw=3, color='#D2292D', label='Target')]
    ax0.legend(handles=legend_elements,loc='upper left',fontsize=16)
    
        
    sns.despine()
    plt.savefig('fig_stat_12.pdf',bbox_inches='tight')
    plt.show()

# %%
bce_arr_p_tRNN = []
p_r2_arr_p_tRNN = []
all_p_0_p_tRNN = []
norm_ll_arr_p_tRNN = []

for i in range(10):
        
    pp = np.stack(((alpha_trnn[i]), (beta_trnn[i]))).T
    
    acc,p_0 = q_pred_ns(all_data[i],pp)
    all_p_0_p_tRNN.append(p_0)
    
    loss = bce_loss(1 - p_0, all_data[i].action.values)
    bce_arr_p_tRNN.append(loss.mean())
    p_r2_arr_p_tRNN.append( 1 - (np.array(loss.sum()) / (-len(cur_df)*np.log(0.5))))
    norm_ll_arr_p_tRNN.append(np.exp(-loss.mean()))
    
np.array(bce_arr_p_tRNN).mean()

# %%
pd.DataFrame({'subject':np.arange(10),
              'bce':bce,
              'psr2':psr,
              'norm_ll':norm_ll
              }).to_csv('../results/samejima_trnn.csv',index=False)

pd.DataFrame({'subject':np.concatenate([np.repeat(i,len(all_data[i])) for i in range(10)]),
              'alpha':np.concatenate(predict_alpha_array),
              'beta':np.concatenate(predict_beta_array),
              'p_0':np.concatenate(predict_p_0_array)
             }).to_csv('../results/samejima_trnn_param.csv',index=False)
