# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import lines
from matplotlib.lines import Line2D
from scipy import stats
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dezfouli_trnn_wo_concat = np.array([0.4011011 , 0.42632353, 0.37720848, 0.18732344, 0.28636873,
       0.56789327, 0.22640237, 0.6045108 , 0.28285001, 0.43913404,
       0.41585472, 0.22807882, 0.50430578, 0.19586913, 0.21114769,
       0.12155021, 0.20194951, 0.65753689, 0.65289013, 0.45364264,
       0.54100546, 0.42892052, 0.10119559, 0.30216666, 0.40548364,
       0.15904666, 0.49693264, 0.32411736, 0.2746107 , 0.5914905 ,
       0.22043217, 0.31354357, 0.66470902, 0.41323241, 0.33733593,
       0.5840546 , 0.07519389, 0.23480416, 0.59947148, 0.12409894,
       0.46924841, 0.16235647, 0.40554925, 0.63103848, 0.42464278,
       0.30038426, 0.34098614, 0.28212677, 0.38690416, 0.13092206,
       0.57292327, 0.68715608, 0.53812509, 0.22691021, 0.15416644,
       0.11815801, 0.32697885, 0.42186224, 0.15981414, 0.28752887,
       0.48926956, 0.55041874, 0.37277936, 0.18529175, 0.20696986,
       0.45218909, 0.40219618, 0.18132523, 0.35454909, 0.14754472,
       0.38026378, 0.21558283, 0.28802072, 0.45828039, 0.22230749,
       0.3107696 , 0.47267801, 0.49433903, 0.22131799, 0.43610323,
       0.2959296 , 0.17267865, 0.15017618, 0.13081074, 0.22609468,
       0.52875058, 0.25097461, 0.07810333, 0.29257272, 0.23387309,
       0.12285859, 0.07148404, 0.26997698, 0.22930661, 0.37237047,
       0.30314553, 0.13442857, 0.11744042, 0.16558367, 0.14373039,
       0.49116716])


dezfouli_trnn_w_concat = np.array([0.4143197 , 0.45224853, 0.35147968, 0.16672407, 0.26410477,
       0.59293149, 0.20640568, 0.63834161, 0.27462846, 0.55493864,
       0.42265255, 0.22489789, 0.52077153, 0.18396557, 0.23401443,
       0.11058996, 0.19799337, 0.65044011, 0.64226355, 0.4342056 ,
       0.5179696 , 0.42064573, 0.06770785, 0.33002786, 0.4339297 ,
       0.1348633 , 0.47075679, 0.32282563, 0.27534908, 0.59531762,
       0.21148135, 0.30880754, 0.66307719, 0.37535458, 0.38326762,
       0.56939689, 0.06940612, 0.23701816, 0.59750366, 0.11072687,
       0.46293822, 0.1421754 , 0.40524638, 0.63715382, 0.43605907,
       0.30799632, 0.3556487 , 0.25264691, 0.38288948, 0.13002684,
       0.56370681, 0.6723608 , 0.52211015, 0.19722078, 0.1402795 ,
       0.10583766, 0.29087329, 0.40339592, 0.14878846, 0.27208814,
       0.47541871, 0.55239732, 0.37290923, 0.15590526, 0.19306238,
       0.43055513, 0.39758663, 0.15931928, 0.3367852 , 0.11648807,
       0.36214295, 0.19895265, 0.27935508, 0.47114062, 0.20608506,
       0.30951134, 0.48506414, 0.47905544, 0.18844279, 0.4223346 ,
       0.2780696 , 0.15605122, 0.12656216, 0.11823472, 0.1977356 ,
       0.545399  , 0.23629134, 0.07679632, 0.27837769, 0.24085838,
       0.12522211, 0.06487326, 0.23206043, 0.22176354, 0.36635359,
       0.30255589, 0.11947925, 0.08467375, 0.14251949, 0.1273773 ,
       0.49442263])

stats.wilcoxon(dezfouli_trnn_wo_concat,dezfouli_trnn_w_concat)

# %%
gershman_trnn_wo_concat = np.array([0.39991342, 0.25589673, 0.24980707, 0.31510114, 0.24009698,
       0.28983812, 0.28869792, 0.47441706, 0.29141233, 0.22480887,
       0.42576994, 0.17510471, 0.30695418, 0.36765735, 0.23991952,
       0.31942494, 0.25501441, 0.34642092, 0.44366248, 0.24245289,
       0.28602503, 0.34946845, 0.34478085, 0.32606899, 0.27434235,
       0.33859888, 0.54390051, 0.34052721, 0.40939054, 0.33939504,
       0.34022683, 0.41384821, 0.38961586, 0.4948568 , 0.20854732,
       0.34677943, 0.2659432 , 0.2647531 , 0.20186264, 0.39219915,
       0.38306413, 0.36755633, 0.30808354, 0.30445354])

gershman_trnn_w_concat = np.array([0.39792599, 0.25125596, 0.24374389, 0.31028868, 0.24316553,
       0.28773514, 0.2848052 , 0.46182819, 0.30196283, 0.23730301,
       0.42682137, 0.16988626, 0.29219235, 0.3986197 , 0.2343282 ,
       0.31225334, 0.24022446, 0.34613942, 0.41559415, 0.2620751 ,
       0.27006546, 0.32383685, 0.35531107, 0.3202937 , 0.27396523,
       0.3197607 , 0.51345922, 0.33565016, 0.40194996, 0.32749867,
       0.34036115, 0.36007436, 0.36688306, 0.48702788, 0.20818395,
       0.35206686, 0.26729368, 0.25375282, 0.20719349, 0.37813372,
       0.39734186, 0.34223665, 0.29819827, 0.29899377])

stats.wilcoxon(gershman_trnn_wo_concat,gershman_trnn_w_concat)

# %%
x = sns.blend_palette(['tab:green','#ffc100','#D2292D','grey','#1761B0'])[2]
pla = ['tab:green','#1761B0',x]

new_df = pd.DataFrame({'BCE':np.concatenate((dezfouli_trnn_wo_concat,dezfouli_trnn_w_concat,
                                   gershman_trnn_wo_concat,gershman_trnn_w_concat)),
              'Data':np.concatenate((np.repeat('Dezfouli',202),np.repeat('Gershman',88))),
              'Model':np.concatenate(((np.repeat('wo/ Concat',101),np.repeat('w/ Concat',101),
                                       np.repeat('wo/ Concat',44),np.repeat('w/ Concat',44))))})


fig , ax = plt.subplots(1,1,figsize=(4,4))

sns.barplot(ax=ax,data=new_df, x='Data',y='BCE',
            hue='Model',palette=pla,edgecolor='k',errorbar="se")

ax.set_xticklabels(['Dezfouli','Gershman'],fontsize=16)
ax.set_xlabel('Dataset',size=22)

ax.set_ylim(0,0.4)
ax.set_yticks([.1,.3])
ax.set_yticklabels([.1,.3],fontsize=20)
ax.set_ylabel('Error (lower is better)',size=20,labelpad=0)




h = 0
line = lines.Line2D([-.25,-.25,0.25,0.25], [.36,.36+h,.36+h,.36], lw=1, c='0.2', transform=ax.transData)
line.set_clip_on(False)
ax.add_line(line)
ax.annotate('***', xy=(np.mean([-.22, 0.25]),.36),
            xytext=(0, 1), textcoords='offset points',
            xycoords='data', ha='center', va='bottom',
            fontsize=16, clip_on=False, annotation_clip=False)

line = lines.Line2D([0.75,0.75,1.25,1.25], [.36,.36+h,.36+h,.36], lw=1, c='0.2', transform=ax.transData)
line.set_clip_on(False)
ax.add_line(line)
ax.annotate('**', xy=(np.mean([.8, 1.25]),.36),
            xytext=(0, 1), textcoords='offset points',
            xycoords='data', ha='center', va='bottom',
            fontsize=16, clip_on=False, annotation_clip=False)

sns.despine()

ax.legend(fontsize=14)

plt.savefig('figS12.pdf',bbox_inches='tight')
plt.show()

# %%
data = np.load('1_param.npz')
t_parameters = data['arr_0']
para = data['arr_1']
predict_trnn_alpha = data['arr_2']
predict_trnn_alpha = np.concatenate((predict_trnn_alpha[:,25::25],predict_trnn_alpha[:,-1].reshape(150,1)),axis=1)

df_mle = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - para[:,:,0].T)**2))
mle_mean_1 = df_mle.mean(axis=0)
mle_error_1 = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - predict_trnn_alpha)**2))
trnn_mean_1 = df_trnn.mean(axis=0)
trnn_error_1 = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_1_alpha = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])

display(df_res_1_alpha)

# %%
data = np.load('2_param.npz')
t_parameters = data['arr_0']
para = data['arr_1']
predict_trnn_alpha = data['arr_2']
predict_trnn_alpha = np.concatenate((predict_trnn_alpha[:,25::25],predict_trnn_alpha[:,-1].reshape(150,1)),axis=1)
predict_trnn_beta = data['arr_3']
predict_trnn_beta = np.concatenate((predict_trnn_beta[:,25::25],predict_trnn_beta[:,-1].reshape(150,1)),axis=1)

df_mle = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - para[:,:,0].T)**2))
mle_mean_2_alpha = df_mle.mean(axis=0)
mle_error_2_alpha = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - predict_trnn_alpha)**2))
trnn_mean_2_alpha = df_trnn.mean(axis=0)
trnn_error_2_alpha = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_2_alpha = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])

df_mle = (pd.DataFrame((np.repeat(t_parameters[:,1],40).reshape(150,40) - para[:,:,1].T)**2))
mle_mean_2_beta = df_mle.mean(axis=0)
mle_error_2_beta = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,1],40).reshape(150,40) - predict_trnn_beta)**2))
trnn_mean_2_beta = df_trnn.mean(axis=0)
trnn_error_2_beta = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_2_beta = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])

display(df_res_2_alpha)
display(df_res_2_beta)

# %%
stats.ttest_rel(df_res_3_alpha['SD (MLE)'],df_res_3_alpha['SD (tRNN)'])

# %%
data = np.load('3_param.npz')
t_parameters = data['arr_0']
para = data['arr_1']
predict_trnn_alpha = data['arr_2']
predict_trnn_alpha = np.concatenate((predict_trnn_alpha[:,25::25],predict_trnn_alpha[:,-1].reshape(150,1)),axis=1)

predict_trnn_beta = data['arr_3']
predict_trnn_beta = np.concatenate((predict_trnn_beta[:,25::25],predict_trnn_beta[:,-1].reshape(150,1)),axis=1)

predict_trnn_kappa = data['arr_4']
predict_trnn_kappa = np.concatenate((predict_trnn_kappa[:,25::25],predict_trnn_kappa[:,-1].reshape(150,1)),axis=1)

df_mle = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - para[:,:,0].T)**2))
mle_mean_3_alpha = df_mle.mean(axis=0)
mle_error_3_alpha = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,0],40).reshape(150,40) - predict_trnn_alpha)**2))
trnn_mean_3_alpha = df_trnn.mean(axis=0)
trnn_error_3_alpha = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_3_alpha = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])


df_mle = (pd.DataFrame((np.repeat(t_parameters[:,1],40).reshape(150,40) - para[:,:,1].T)**2))
mle_mean_3_beta = df_mle.mean(axis=0)
mle_error_3_beta = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,1],40).reshape(150,40) - predict_trnn_beta)**2))
trnn_mean_3_beta = df_trnn.mean(axis=0)
trnn_error_3_beta = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_3_beta = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])

df_mle = (pd.DataFrame((np.repeat(t_parameters[:,2]+0.5,40).reshape(150,40) - para[:,:,2].T)**2))
mle_mean_3_kappa = df_mle.mean(axis=0)
mle_error_3_kappa = df_mle.sem(axis=0)

df_trnn = (pd.DataFrame((np.repeat(t_parameters[:,2],40).reshape(150,40) - predict_trnn_kappa)**2))
trnn_mean_3_kappa = df_trnn.mean(axis=0)
trnn_error_3_kappa = df_trnn.sem(axis=0)

all_res = []
for i in range(40):
    sta,pval = stats.ttest_rel(df_mle.values[:,i],df_trnn.values[:,i])
    mu1,mu2 = df_mle.values[:,i].mean(),df_trnn.values[:,i].mean()
    sig1,sig2 = df_mle.values[:,i].std(),df_trnn.values[:,i].std()
    all_res.append([sta,pval,mu1,mu2,sig1,sig2])
df_res_3_kappa = pd.DataFrame(data=all_res,columns=['statistic','pvalue','M (MLE)','M (tRNN)','SD (MLE)','SD (tRNN)'])


display(df_res_3_alpha)
display(df_res_3_beta)
display(df_res_3_kappa)

# %%
fig, axes = plt.subplots(figsize=(8, 8), ncols=3, nrows=3)

for i in range(3):
    
    if i == 0: 
        mle_mean,mle_error = mle_mean_1, mle_error_1 
        trnn_mean,trnn_error = trnn_mean_1, trnn_error_1
        
    for j in range(3):
        
        if i==1 and j==0:
            mle_mean, mle_error = mle_mean_2_alpha, mle_error_2_alpha 
            trnn_mean, trnn_error = trnn_mean_2_alpha, trnn_error_2_alpha
        
        if i==1 and j==1:
            mle_mean, mle_error = mle_mean_2_beta, mle_error_2_beta
            trnn_mean, trnn_error = trnn_mean_2_beta, trnn_error_2_beta
            
        if i==2 and j==0:
            mle_mean, mle_error = mle_mean_3_alpha, mle_error_3_alpha 
            trnn_mean, trnn_error = trnn_mean_3_alpha, trnn_error_3_alpha
            
        if i==2 and j==1:
            mle_mean, mle_error = mle_mean_3_beta, mle_error_3_beta
            trnn_mean, trnn_error = trnn_mean_3_beta, trnn_error_3_beta
                    
        if i==2 and j==2:
            mle_mean, mle_error = mle_mean_3_kappa, mle_error_3_kappa
            trnn_mean, trnn_error = trnn_mean_3_kappa, trnn_error_3_kappa
            
        if i<j:
            axes[i, j].axis('off')
            
        else:

            sns.lineplot(ax=axes[i, j],data=mle_mean,color='tab:green')
            axes[i, j].fill_between(np.arange(0,40),mle_mean-mle_error,
                                         mle_mean+mle_error,alpha=.2,color='tab:green')

            sns.lineplot(ax=axes[i, j],data=trnn_mean,color='#1761B0')
            axes[i, j].fill_between(np.arange(0,40),trnn_mean-trnn_error,
                                         trnn_mean+trnn_error,alpha=.2,color='#1761B0')
            
            axes[2, j].set_xlabel('Trial',size=14)
            axes[i, 0].set_ylabel(r'$MSE$',size=16)
            axes[i, j].set_xticks([0,19,39])
            axes[i, j].set_xticklabels([25,500,1000])
            axes[i, j].set_xlim(-1,41)
            axes[i, j].tick_params(axis='both', which='major', labelsize=14)

#             axes[i, j].set_yscale('log')

            x1 = -1
            x2 = 4

            y1 = trnn_mean[5]
            y2 = (trnn_mean[0]+mle_mean[0])/2

            axins = zoomed_inset_axes(axes[i, j], 1) # zoom = 2

            sns.lineplot(ax=axins,data=mle_mean,color='tab:green')
            # axins.fill_between(np.arange(0,40),mle_mean-mle_error,
            # mle_mean+mle_error,alpha=.2,color='tab:green')

            sns.lineplot(ax=axins,data=trnn_mean,color='#1761B0')
            # axins.fill_between(np.arange(0,40),trnn_mean-trnn_error,
            # trnn_mean+trnn_error,alpha=.2,color='#1761B0')

            axins.set_xlim(x1, x2)
            axins.set_ylim(y1, y2)
            plt.xticks(visible=False)
            plt.yticks(visible=False)
            mark_inset(axes[i, j], axins, loc1=2, loc2=4, fc="none", ec="0.5")
            plt.draw()

# axes[0, 0].text(x=-50,y=0.05,s='Exp. 1',fontsize=15)
# axes[1, 2].text(x=1,y=0.5,s='Exp. 2',fontsize=15)
# axes[2, 2].text(x=40,y=0.02,s='Exp. 3',fontsize=15)
        
axes[0, 0].set_title(r'$\alpha$',size=20)
axes[1, 1].set_title(r'$\beta$',size=20)
axes[2, 2].set_title(r'$\kappa$',size=20)


legend_elements = [
                Line2D([0],[0] ,lw=3, marker='o',ms=0,  color='tab:green', label='Stationary (MLE)'),
                Line2D([0],[0] ,lw=3, marker='o',ms=0, color='#1761B0', label='t-RNN')
]
axes[0, 1].legend(handles=legend_elements,fontsize=14)


sns.despine()
plt.tight_layout()
plt.savefig('figS12.pdf')
plt.show()
